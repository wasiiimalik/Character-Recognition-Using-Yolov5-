# %% [markdown]
# <h1> Webcam Implementation For the YoloV5 trained Weights</h1>

# %%
#!pip install git+https://github.com/philferriere/cocoapi.git#egg=pycocotools^&subdirectory=PythonAPI

# %%
# !python detect.py --weights runs/train/yolov5s_results/weights/best.pt --img 416 --conf 0.4 --source 0
# Out:
# Namespace(weights=['runs/train/yolov5s_results/weights/best.pt'], source='0', img_size=416, conf_thres=0.4, iou_thres=0.45, device='', view_img=False, save_txt=False, save_conf=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False)
# C:\Users\thewa\anaconda3\lib\site-packages\requests\__init__.py:109: RequestsDependencyWarning: urllib3 (1.26.7) or chardet (2.0.3)/charset_normalizer (2.0.4) doesn't match a supported version!
#   warnings.warn(
# YOLOv5 v4.0-126-g886f1c03 torch 1.11.0 CUDA:0 (NVIDIA GeForce GTX 1050, 4095.8125MB)
#
# C:\Users\thewa\anaconda3\lib\site-packages\torch\functional.py:568: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\TensorShape.cpp:2228.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...
